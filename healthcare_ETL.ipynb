# %%
- Note: This dataset is synthetic and does not represent real-world
- healthcare records. The analysis results should not be interpreted
- as actual healthcare statistics or used for real-world decisions.

# %% [markdown]
# ## Extract

# %%
import pandas as pd

# %%
pip install pandas sqlalchemy pyodbc

# %%
df = pd.read_csv("healthcare_dataset.csv")

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %% [markdown]
# ## Explore and Transform

# %%
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
df.shape
# Out:
# (55500, 15)

# %%
df.duplicated().sum()
# Out:
# 534

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (54966, 15)

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'])
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'])

# %%
df['Length of Stay'] = (
    df['Discharge Date'] - df['Date of Admission']
).dt.days

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df['Name'] = df['Name'].str.title()

# %%
df['Age'].describe()
# Out:
# count    54966.000000
# mean        51.535185
# std         19.605661
# min         13.000000
# 25%         35.000000
# 50%         52.000000
# 75%         68.000000
# max         89.000000
# Name: Age, dtype: float64

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["Blood Type"].unique()
# Out:
# array(['B-', 'A+', 'A-', 'O+', 'AB+', 'AB-', 'B+', 'O-'], dtype=object)

# %%
df["Medical Condition"].unique()
# Out:
# array(['Cancer', 'Obesity', 'Diabetes', 'Asthma', 'Hypertension',
#        'Arthritis'], dtype=object)

# %%
df["Doctor"].sample(20)
# Out:
# 25275         Krystal Dixon
# 54861            Lisa Jones
# 10016         Joshua Watson
# 10770           Kevin Davis
# 19036       Sharon Franklin
# 22800        Allison Carter
# 17380        Victor Sanders
# 17138       Richard Griffin
# 52525        Anthony Kramer
# 29861         James Herring
# 73               Raven Wong
# 29494       Ashley Chambers
# 6599     Mr. Ryan Adams DDS
# 20092          Ashley Lewis
# 48216             John Cruz
# 30192          Julia Valdez
# 21767    Christopher Wright
# 4833     Christopher Morgan
# 26142      Anthony Martinez
# 5371      Michelle Sullivan
# Name: Doctor, dtype: object

# %%
df["Doctor"].value_counts()
# Out:
# Doctor
# Michael Smith      27
# John Smith         22
# Robert Smith       21
# James Smith        20
# Michael Johnson    20
#                    ..
# Shane Tate          1
# Christy Parker      1
# Larry Miller        1
# Chelsea Neal        1
# Jeffrey Moore       1
# Name: count, Length: 40341, dtype: int64

# %%
df["Hospital"].sample(20)
# Out:
# 13595         Lyons and Foster Rodgers,
# 9841      Anderson and Sullivan Rivera,
# 28212          Lopez, Jones Schmidt and
# 12503                   Mcguire-Johnson
# 12890              Hale, Lowe Gates and
# 2914                       Wright Group
# 31362                         Ltd Clark
# 39055            Wells Roberts, and Lee
# 36191                          Le-Henry
# 15693          and Dennis Ross Hopkins,
# 7420          and Bowers Morrow Conrad,
# 29182                     Rodgers-Davis
# 43989          and Adams Martin, Thomas
# 3896        and Richards Barrera, Olson
# 42130      and Matthews, Wright Lambert
# 22849                     Wilson-Taylor
# 51273                   Johnson-Andrade
# 16508                      Hill-Gilbert
# 23269    Cunningham Burke and Ferguson,
# 52834                          PLC Hart
# Name: Hospital, dtype: object

# %%
df["Hospital"].value_counts()
# Out:
# Hospital
# LLC Smith                       44
# Ltd Smith                       39
# Johnson PLC                     37
# Smith Ltd                       37
# Smith Group                     36
#                                 ..
# PLC Navarro                      1
# PLC Mcintosh                     1
# and Hernandez, Hughes Walton     1
# Myers-Williams                   1
# Moreno Murphy, Griffith and      1
# Name: count, Length: 39876, dtype: int64

# %%
df["Insurance Provider"].unique()
# Out:
# array(['Blue Cross', 'Medicare', 'Aetna', 'UnitedHealthcare', 'Cigna'],
#       dtype=object)

# %%
df['Billing Amount'].describe()
# Out:
# count    54966.000000
# mean     25544.306284
# std      14208.409711
# min      -2008.492140
# 25%      13243.718641
# 50%      25542.749145
# 75%      37819.858159
# max      52764.276736
# Name: Billing Amount, dtype: float64

# %%
negative_billing = df[df['Billing Amount'] < 0]
len(negative_billing)
# Out:
# 106

# %%
negative_billing = df[df['Billing Amount'] < 0]

negative_billing.head(20)
# Out:
#                            Name  Age  Gender Blood Type Medical Condition  \
# 132             Ashley Erickson   32  Female        AB-            Cancer
# 799           Christopher Weiss   49  Female        AB-            Asthma
# 1018              Ashley Warner   60    Male         A+      Hypertension
# 1421               Jay Galloway   74  Female         O+            Asthma
# 2103          Joshua Williamson   72  Female         B-          Diabetes
# 2696              Scott Vazquez   74    Male         B+          Diabetes
# 2855             Carol Anderson   39  Female         B-      Hypertension
# 3772   Mr. Christopher Alvarado   77    Male        AB+           Obesity
# 5445             Alexandra Khan   32    Male        AB+         Arthritis
# 5708                 Joseph Cox   23    Male        AB-          Diabetes
# 6336         Mitchell Maldonado   41  Female         A+            Asthma
# 6596            Julie Christian   28  Female        AB+          Diabetes
# ...

# %%
# Data Quality Check — Billing Amount

#106 records contain negative billing amounts.Therefore, these records will be removed.

df.drop(
    df[df['Billing Amount'] < 0].index,
    inplace=True
)

# %%
df['Billing Amount'].min()
# Out:
# 9.238787497393332

# %%
df['Room Number'].describe()
# Out:
# count    54860.000000
# mean       301.109752
# std        115.217195
# min        101.000000
# 25%        202.000000
# 50%        302.000000
# 75%        400.000000
# max        500.000000
# Name: Room Number, dtype: float64

# %%
df["Admission Type"].unique()
# Out:
# array(['Urgent', 'Emergency', 'Elective'], dtype=object)

# %%
df["Medication"].unique()
# Out:
# array(['Paracetamol', 'Ibuprofen', 'Aspirin', 'Penicillin', 'Lipitor'],
#       dtype=object)

# %%
df["Test Results"].unique()
# Out:
# array(['Normal', 'Inconclusive', 'Abnormal'], dtype=object)

# %%
df["Length of Stay"].describe()
# Out:
# count    54860.000000
# mean        15.498815
# std          8.661357
# min          1.000000
# 25%          8.000000
# 50%         15.000000
# 75%         23.000000
# max         30.000000
# Name: Length of Stay, dtype: float64

# %%
df.insert(0, 'Admission_ID', range(1, len(df) + 1))

# %%
df
# Out:
#        Admission_ID               Name  Age  Gender Blood Type  \
# 0                 1      Bobby Jackson   30    Male         B-
# 1                 2       Leslie Terry   62    Male         A+
# 2                 3        Danny Smith   76  Female         A-
# 3                 4       Andrew Watts   28  Female         O+
# 4                 5      Adrienne Bell   43  Female        AB+
# ...             ...                ...  ...     ...        ...
# 55495         54856  Elizabeth Jackson   42  Female         O+
# 55496         54857         Kyle Perez   61  Female        AB-
# 55497         54858       Heather Wang   38  Female         B+
# 55498         54859     Jennifer Jones   43    Male         O-
# 55499         54860       James Garcia   53  Female         O+
#
#       Medical Condition Date of Admission            Doctor  \
# 0                Cancer        2024-01-31     Matthew Smith
# 1               Obesity        2019-08-20   Samantha Davies
# ...

# %% [markdown]
# ## Loading

# %%
from sqlalchemy import create_engine
import urllib

params = urllib.parse.quote_plus(
    "DRIVER={ODBC Driver 18 for SQL Server};"
    "SERVER=YOUR_SERVER;"
    "DATABASE=YOUR_DATABASE;"
    "Trusted_Connection=yes;"
    "TrustServerCertificate=yes;"
)

engine = create_engine(
    f"mssql+pyodbc:///?odbc_connect={params}"
)

# %%
with engine.connect() as connection:
    print("Connected successfully!")
# Out:
# Connected successfully!

# %%
df.to_sql(
    name='healthcare_admissions',
    con=engine,
    if_exists='append',
    index=False
)
